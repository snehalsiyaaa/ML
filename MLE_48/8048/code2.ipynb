# %%
pip install numpy pandas matplotlib seaborn scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
data = pd.read_csv("student_scores.csv")
data.head(10)
# Out:
#      name  hours  score gender grades class
# 0   Aarav      8     76      M      A    9A
# 1    Riya      5     62      F      B    9B
# 2   Kabir     10     88      M      A   10A
# 3    Sana      4     55      F      C    9A
# 4  Vivaan      7     72      M      B   10B
# 5  Ishita      6     64      F      B    9C
# 6   Rohan      3     48      M      D    9B
# 7   Meera      9     90      F      A   11A
# 8  Aditya      2     38      M      F    9C
# 9   Kavya     11     93      F      A   12A

# %%
print('Columns:', data.columns.tolist())
print('\nInfo:')
print(data.info())
print('\nDescribe:')
display(data.describe())
# Out:
# Columns: ['name', 'hours', 'score', 'gender', 'grades', 'class']
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    92 non-null     object
#  1   hours   92 non-null     int64
#  2   score   92 non-null     int64
#  3   gender  92 non-null     object
#  4   grades  92 non-null     object
#  5   class   92 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 4.4+ KB
# None
#
# Describe:
#            hours      score
# count  92.000000  92.000000
# mean    6.510870  68.836957
# std     2.265336  15.692286
# min     2.000000  35.000000
# 25%     5.000000  57.000000
# 50%     7.000000  70.000000
# 75%     8.000000  82.000000
# max    11.000000  94.000000

# %%
print(data.isnull().sum())
data["score"] =data["score"].fillna(data["score"].mean())
data =data.dropna()
print()
# Out:
# name      0
# hours     0
# score     0
# gender    0
# grades    0
# class     0
# dtype: int64

# %%
data.shape
# Out:
# (92, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    92 non-null     object
#  1   hours   92 non-null     int64
#  2   score   92 non-null     int64
#  3   gender  92 non-null     object
#  4   grades  92 non-null     object
#  5   class   92 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 4.4+ KB

# %%
#Completeness
data.isnull().sum()
# Out:
# name      0
# hours     0
# score     0
# gender    0
# grades    0
# class     0
# dtype: int64

# %%
# check Dataset Consistency
data.dtypes
# Out:
# name      object
# hours      int64
# score      int64
# gender    object
# grades    object
# class     object
# dtype: object

# %%
#Accuracy( to see realistic values or outliers)
data.describe()
data['hours'].plot(kind='box')
# Out:
# <Axes: >

# %%
# Time Keeping - is data up to date ?
data['score'].max()
data['score'].min()
# Out:
# 35

# %%
#BIAS Check
data['grades'].value_counts(normalize=True)
# Out:
# grades
# B    0.358696
# A    0.326087
# C    0.195652
# D    0.086957
# F    0.032609
# Name: proportion, dtype: float64

# %% [markdown]
# # Dataset Specification Sheet
#
# | **Field** | **Details** |
# |----------|-------------|
# | **Dataset Name** | `student_scores.csv` |
# | **Description** | Contains student study hours, scores, gender, grade categories (A–F), and class sections (9A–12C). Useful for academic analytics, performance prediction, and data-quality demonstrations. |
# | **Features** | `name`, `hours`, `score`, `gender`, `grades`, `class` |
# | **Target Variable** | *None explicitly.*<br>Can be used for:<br>• **Regression:** predicting `score`<br>• **Classification:** predicting `grades` |
# | **Number of Rows** | 100 (based on provided data) |
# | **Null Handling** | No missing values present.<br>If needed:<br>• Numerical → mean/median imputation<br>• Categorical → mode imputation |
# | **Transformations** | • Checked datatypes (`data.dtypes`)<br>• Summary statistics (`data.describe()`)<br>• Boxplot for study hours (`data['hours'].plot(kind='box')`)<br>• Grade distribution (`data['grades'].value_counts(normalize=True)`)<br>• Score min/max calculations |
# | **Owner** | Student / Notebook Author |
# | **Last Updated** | 2025-12-09 |

# %%
#Convert Text Columns to Numbers
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data["gender"] = le.fit_transform(data["gender"])
print(data.head(20))
# Out:
#        name  hours  score  gender grades class
# 0     Aarav      8     76       1      A    9A
# 1      Riya      5     62       0      B    9B
# 2     Kabir     10     88       1      A   10A
# 3      Sana      4     55       0      C    9A
# 4    Vivaan      7     72       1      B   10B
# 5    Ishita      6     64       0      B    9C
# 6     Rohan      3     48       1      D    9B
# 7     Meera      9     90       0      A   11A
# 8    Aditya      2     38       1      F    9C
# 9     Kavya     11     93       0      A   12A
# 10    Naman      5     60       1      B   10A
# 11   Jhanvi      7     70       0      B   11B
# 12   Pranav      4     52       1      C    9A
# 13     Tara      9     85       0      A   12B
# 14     Yash      6     66       1      B   10C
# 15    Anaya      8     78       0      A   11A
# 16    Harsh      3     45       1      D    9A
# 17     Diya     10     89       0      A   12C
# 18  Sarthak      6     63       1      B   10B
# ...

# %%
data = pd.read_csv("telecom_dataset.csv")
